# %% [markdown]
# Q1
#
# Exception class is a super class or base class in python and inside there are so many main exception classes to raise an exception error.
#
# Thats why when we made Custom exception we have to inherit Exception class to raise our custom exception error. so this way our custom exception can get all exceptions from super class and also in that we will be able to add our user defined exception.

# %%
import inspect

def tree(cls, ind = 0):
    print('_'*ind , cls.__name__)
    
    for i in cls.__subclasses__():
        tree(i,ind+3)

# %%
tree(BaseException)
# Out:
#  BaseException
# ___ Exception
# ______ TypeError
# _________ FloatOperation
# _________ MultipartConversionError
# ______ StopAsyncIteration
# ______ StopIteration
# ______ ImportError
# _________ ModuleNotFoundError
# _________ ZipImportError
# ______ OSError
# _________ ConnectionError
# ____________ BrokenPipeError
# ____________ ConnectionAbortedError
# ____________ ConnectionRefusedError
# ____________ ConnectionResetError
# _______________ RemoteDisconnected
# _________ BlockingIOError
# _________ ChildProcessError
# _________ FileExistsError
# _________ FileNotFoundError
# _________ IsADirectoryError
# _________ NotADirectoryError
# _________ InterruptedError
# ____________ InterruptedSystemCall
# _________ PermissionError
# _________ ProcessLookupError
# _________ TimeoutError
# _________ UnsupportedOperation
# _________ itimer_error
# _________ herror
# _________ gaierror
# _________ SSLError
# ____________ SSLCertVerificationError
# ____________ SSLZeroReturnError
# ...

# %% [markdown]
# Q3.
#
# ArithmeticError occurs when ther is a error in calculation. There are 3 defined exception are
#
# 1..ZerodivisionError 2..FloatingPointError 3..OveerflowError

# %%
try:
    a = 10/0
    print(a)
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# ZerodivisionError is getting when any number is trying to get divisible by 0.

# %%
try:
    a = 5.0
    for i in range(1,1000):
        a = a**i
        print(a)
except OverflowError as e:
    print(e)
# Out:
# 5.0
# 25.0
# 15625.0
# 5.960464477539062e+16
# 7.52316384526264e+83
# (34, 'Numerical result out of range')

# %% [markdown]
# OverflowError is raised when an aritmetic operation exceeds the limits to be repesented.

# %% [markdown]
# Q4
#
# LookupError class exceptions are raised when an index or a key is not found for a sequence or dictinary respectively.

# %%
#Index Error

try:
    l = [3,4,56,6,7]
    print(l[20])
except Exception as e:
    print(e,e.__class__)
    
# IndexError gets when we access an item from list which is out of range
# Out:
# list index out of range <class 'IndexError'>

# %%
# 2 KeyError
try:
    d = {"key1":"Hello","Key2":"World"}
    print(d["key3"])
except Exception as e:
    print(e,e.__class__)

# KeyError gets when we access the key in the dictionary which doesn't exist.
# Out:
# 'key3' <class 'KeyError'>

# %% [markdown]
# Q5
#
# ImportError occurs when: 1.. The imported class in a circular dependency 2.. The import class is unavailable or was not created 3.. The imported class is misspelled.
#
# ModuleNotFoundError is occurs when the import module was not found or it is misspelled or it is unavailabe.

# %%
try:
    import shailove
except ImportError as e:
    print(e,e.__class__)
# Out:
# No module named 'shailove' <class 'ModuleNotFoundError'>

# %% [markdown]
# Q6.
#
# Best practices for Exception handling:
#
# 1>  We have to always use specific Exception
# 2>  Always use proper print message.
# 3>  Always log ou entire code.
# 4>  Avoid to write multiple exception handling
# 5>  Document all the errors
# 6>  Cleanup all the resource after use.
